# %% [markdown]
# # A Generic Report
# ## A Subtitle

# %%
from nbprint import newpage; newpage()
# Out:
# <p style="page-break-before: always;">
# </p>

# %% [markdown]
# # Section One,
# Lorem ipsum dolor sit amet.
#
# ## Subsection One
#
# Consectetur adipiscing elit, sed do eiusmod tempor incididunt.
#
# ## Subsection Two
#
# Ut labore et dolore magna aliqua.

# %%
from nbprint import newpage; newpage()
# Out:
# <p style="page-break-before: always;">
# </p>

# %% [markdown]
# # Section Two
#
# Lorem ipsum dolor sit amet.
#
# ## Subsection One
#
# Consectetur adipiscing elit, sed do eiusmod tempor incididunt.

# %%
from nbprint import newpage; newpage()
# Out:
# <p style="page-break-before: always;">
# </p>

# %% [markdown]
# # Section Three
#
# Ut labore et dolore magna aliqua.
#
# ## Subsection One
#
# Ut enim ad minim veniam, quis nostrud.

# %%
from superstore import superstore, timeseries
from IPython.display import JSON, Markdown, FileLink

# %% [markdown]
# ## Outputs

# %%
df = superstore()

# %% [markdown]
# ### File

# %%
pth = "superstore.csv"
df.to_csv(pth, index=False)
FileLink(pth)
# Out:
# /Users/timkpaine/Developer/projects/nbprint/nbprint/examples/superstore.csv

# %% [markdown]
# ### JSON

# %%
JSON(df.head().to_dict())

# %% [markdown]
# ### Image

# %%
timeseries().plot();

# %% [markdown]
# ### Bool

# %%
True
# Out:
# True

# %% [markdown]
# ### String

# %%
"abc"
# Out:
# 'abc'
