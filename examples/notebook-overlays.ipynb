# %% [markdown]
# # Sales Dashboard
# ## April 2026

# %% [markdown]
# # Overview
#
# Key metrics and regional breakdown.

# %% [markdown]
# ## North America

# %%
# A placeholder 'chart' cell.
from IPython.display import Markdown, display
display(Markdown("**North America: $420M**"))

# %% [markdown]
# ## Europe

# %%
from IPython.display import Markdown, display
display(Markdown("**Europe: $310M**"))

# %% [markdown]
# # Conclusion
#
# Growth remained strong across both regions.
