# %%
a = 1
b = 2.3
c = "abc"

# %%
print(f"a: {a}, type: {type(a)}")
print(f"b: {b}, type: {type(b)}")
print(f"c: {c}, type: {type(c)}")
# Out:
# a: 1, type: <class 'int'>
# b: 2.3, type: <class 'float'>
# c: abc, type: <class 'str'>
