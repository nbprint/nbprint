# %%
company = 'My Photo Company, Inc.'
start = '05/01/2020'
end = '05/05/2020'

# %%
# ignore this in case any import side effects
from nbcx import display, print, newpage, table, hr, image, pagenum
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

start = datetime.strptime(start, '%m/%d/%Y')
end = datetime.strptime(end, '%m/%d/%Y')

# %%
# Title Bar
print(image("header.png"))
print('# Title for Report')
print('## Report for client: {}'.format(company))
print('Running from {} to {}'.format(start, end))
# Out:
# # Title for Report
# ## Report for client: My Photo Company, Inc.
# Running from 2020-05-01 00:00:00 to 2020-05-05 00:00:00

# %%
print('Overview', color='red')
# Out:
# Overview

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if isinstance(val, float) and val < 0 else 'black'
    return 'color: %s' % color


df = pd.DataFrame({
    'First': ['A', 'B', 'C'],
    'Second': [1, -2, 3],
    'Third': ['ABC', 'DEF', 'GHI'],
    'Fourth': [-1.5, -0.4, 4.5]
})
df.style.applymap(color_negative_red) \
    .bar(subset=['Second'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row0_col0 {
#             color:  black;
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row0_col1 {
#             color:  black;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.0%, #5fba7d 40.0%, #5fba7d 60.0%, transparent 60.0%);
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row0_col2 {
#             color:  black;
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row0_col3 {
#             color:  red;
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row1_col0 {
#             color:  black;
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row1_col1 {
#             color:  black;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }    #T_2d8fb2c2_9335_11ea_aca9_820f0ed38380row1_col2 {
#             color:  black;
# ...

# %%
pd.DataFrame(pd.util.testing.getTimeSeriesData()).plot()
plt.show()

sns.heatmap(pd.DataFrame(pd.util.testing.getTimeSeriesData()).corr())
plt.show()

# %%
display(pd.DataFrame(pd.util.testing.getTimeSeriesData()))
pd.DataFrame(pd.util.testing.getMixedTypeDict())
# Out:
#                    A         B         C         D
# 2000-01-03  0.562777  0.186114 -0.682262 -0.261335
# 2000-01-04  1.849068  0.053737 -1.649624 -1.999953
# 2000-01-05  1.219066  0.687306  2.945246  1.690926
# 2000-01-06  1.326758  0.511827 -0.639203 -0.908932
# 2000-01-07  0.364758  1.796902  1.223742  1.971615
# 2000-01-10 -1.197378 -0.165167 -1.156313  0.444304
# 2000-01-11  0.778091 -1.559595 -0.693454 -0.178044
# 2000-01-12  0.529342 -1.489488 -0.401838  0.012454
# 2000-01-13  0.028471  0.564958  0.068278 -0.292724
# 2000-01-14  0.288543 -0.027554  1.459912  0.096555
# 2000-01-17 -0.089648  1.921218 -0.282909 -0.832659
# 2000-01-18  0.716550  1.679556 -0.936577 -0.184245
# 2000-01-19  2.056723 -1.669036  0.914946  0.871880
# 2000-01-20  0.087255  0.649408 -0.249409  0.548697
# 2000-01-21  0.083488 -0.968789 -1.052016 -0.108648
# 2000-01-24  0.161334 -1.259949 -0.483454  2.154193
# 2000-01-25  1.134451 -1.396947 -1.026979  0.177287
# ...

# %%
print('Subsection', color='red')
pd.DataFrame(pd.util.testing.getTimeSeriesData()).plot();
# Out:
# Subsection

# %%
print('Endnotes', color='red')
print('# Lorem ipsum')
print('msdlfkgnsld ngslkdfn slkgndflk gnskdfngskldfngansdlaknsldk gndflkgsndf lk gnsldfkngskl dfngskldfngklsdfngkls dnfgkls ndfklgn sf')
# Out:
# Endnotes
# # Lorem ipsum
# msdlfkgnsld ngslkdfn slkgndflk gnskdfngskldfngansdlaknsldk gndflkgsndf lk gnsldfkngskl dfngskldfngklsdfngkls dnfgkls ndfklgn sf
